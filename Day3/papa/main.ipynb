# %%
import openai
import dotenv
dotenv.load_dotenv()

client = openai.OpenAI()

messages = []

def call_llm():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI : {message}")

while True:
    message = input("Send a message to the LLM")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User : {message}")
        call_llm()
# Out:
# User : 바다거북이의 평균 수명은?
# AI : 바다거북이의 평균 수명은 종류에 따라 다양하지만, 대부분의 바다거북이는 50년에서 100년 이상 살 수 있습니다. 일부 특정 종류의 바다거북이는 150년 이상 살기도 합니다. 예를 들어, 아 대서양거북이나 흑염소바다거북은 80년에서 100년 이상 살 수 있다고 알려져 있습니다. 그러나 바다거북의 정확한 수명은 환경, 서식지, 질병 등 여러 요인에 따라 달라질 수 있습니다.
# User : 방금 내가 평균 수명 물어본 동물의 천적은?
# AI : 바다거북이의 주요 천적은 다음과 같습니다:
#
# 1. **상어**: 특히 큰 상어 종류인 백상아리와 호랑이 상어가 바다거북을 사냥할 수 있습니다.
# 2. **돌고래**: 일부 돌고래 종도 바다거북을 공격하기도 합니다.
# 3. **큰 해양 조류**: 특히 바다거북의 알과 유충을 먹는 큰 해양 새들이 있습니다.
# 4. **인간**: 해양에서의 인간의 활동(낚시, 해안 개발, 오염 등)과 밀렵, 바다거북의 알을 채취하는 행위 등으로 인해 직접적으로 영향을 받습니다.
#
# 이 외에도 바다거북의 유충과 어린 바다거북은 다양한 포식자에게 노출될 수 있습니다.
